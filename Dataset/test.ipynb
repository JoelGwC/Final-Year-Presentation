# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('test.txt', sep=r'\s+')
yvalues = df['idW'].to_list()
xvalues = df['gm_Id'].to_list()
print(yvalues)
print(xvalues)
# Out:
# [3e-06, 6e-06, 1.2e-05, 2.4e-05, 4.6e-05, 8.8e-05, 0.000169, 0.000323, 0.000617, 0.001172, 0.002216, 0.004163, 0.007754, 0.014285, 0.025952, 0.046327, 0.080956, 0.138004, 0.228866, 0.368748, 0.5774, 0.880361, 1.31102, 1.913531, 2.746128, 3.88386, 5.419188, 7.458324, 10.111251, 13.474624, 17.610021, 22.524821, 28.165534, 34.42835, 41.180977, 48.284696, 55.609798, 63.043623, 70.493235, 77.884905, 85.162016, 92.28237, 99.215483, 105.940141, 112.442329, 118.713544, 124.749454, 130.548864, 136.112905, 141.44443, 146.547545]
# ...

# %%
plt.plot(xvalues, yvalues)
plt.show()
